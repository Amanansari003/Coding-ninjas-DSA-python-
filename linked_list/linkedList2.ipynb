# %% [markdown]
# ### reverse the linked list

# %%
class Node :
    def __init__(self,data):
        self.data = data 
        self.next = None 

def reverse(head):
    if head is None :
        return
    if head.next is None :
        return head
    else :
        tail = head.next 
        smallHead = reverse(head.next)
        tail.next = head
        head.next = None 
        return smallHead

def takeInput():
    inputList = [int(u) for u in input().split()]
    head = None 
    tail = None 
    for curr in inputList:
        if curr == -1 :
            break
        else :
            newNode = Node(curr)
            if head is None:
                head = newNode
                tail = newNode
            else :
                tail.next = newNode
                tail = newNode
    return head


def printLL(head):
    while head :
        print(head.data,end = ' ')
        head = head.next 
    print()

head = takeInput()
printLL(head)
value = reverse(head)
printLL(value)
# Out:
# 1 2 3 4
# 4 3 2 1

# %% [markdown]
# ### alternate approache

# %%
class Node :
    def __init__(self,data):
        self.data = data 
        self.next = None 

def reverse(head):
    if head is None or head.next is None  :
        return head,head 
    else :
        smallHead,tail = reverse(head.next)
        tail.next = head
        head.next = None 
        return smallHead,head
    # if head is None or head.next is None:
    #     return head,head
    # smallHead,smallTail=reverse(head.next)
    # smallTail.next=head
    # head.next=None
    # return smallHead,head 

def takeInput():
    inputList = [int(u) for u in input().split()]
    head = None 
    tail = None 
    for curr in inputList:
        if curr == -1 :
            break
        else :
            newNode = Node(curr)
            if head is None:
                head = newNode
                tail = newNode
            else :
                tail.next = newNode
                tail = newNode
    return head


def printLL(head):
    while head :
        print(head.data,end = ' ')
        head = head.next 
    print()

head = takeInput()
printLL(head)
value = reverse(head)
printLL(value[0])
# Out:
# 1 2 3 4
# 4 3 2 1

# %% [markdown]
# ### more alternate approach

# %%
class Node :
    def __init__(self,data):
        self.data = data 
        self.next = None 

def reverse(head):
    if head is None or head.next is None  :
        return head,head
    else :
        smallHead,bcd= reverse(head.next)
        tail = head.next 
        tail.next = head 
        head.next = None
        return smallHead,tail.next


def takeInput():
    inputList = [int(u) for u in input().split()]
    head = None 
    tail = None 
    for curr in inputList:
        if curr == -1 :
            break
        else :
            newNode = Node(curr)
            if head is None:
                head = newNode
                tail = newNode
            else :
                tail.next = newNode
                tail = newNode
    return head


def printLL(head):
    while head :
        print(head.data,end = ' ')
        head = head.next 
    print()

head = takeInput()
printLL(head)
value,tail = reverse(head)
printLL(value)
print(tail.data)
# Out:
# 2 3 4 5 6
# 6 5 4 3 2
# 2

# %% [markdown]
# ### iterative solution of reversing the linked list

# %%
class Node :
    def __init__(self,data):
        self.data = data 
        self.next = None 

def reverse(head):
    pre = None 
    current = head 
    while current :
        Next = current.next 
        current.next = pre 
        pre = current
        current = Next
    return pre


def takeInput():
    inputList = [int(u) for u in input().split()]
    head = None 
    tail = None 
    for curr in inputList:
        if curr == -1 :
            break
        else :
            newNode = Node(curr)
            if head is None:
                head = newNode
                tail = newNode
            else :
                tail.next = newNode
                tail = newNode
    return head


def printLL(head):
    while head :
        print(head.data,end = ' ')
        head = head.next 
    print()

head = takeInput()
printLL(head)
value = reverse(head)
printLL(value)

# %% [markdown]
# ### mid point of the linked list

# %%
class Node :
    def __init__(self,data):
        self.data = data 
        self.next = None 


def length (head) :
    count = 0 
    while head :
        count+=1 
        head = head.next 
    return count 
def midValue(head):
    m = length(head)
    if m > 0 :
        slow = head 
        fast = head 
        if m % 2 != 0 :
            while fast.next :
                slow = slow.next 
                fast = fast.next.next  
            return slow.data
        else :
            while fast.next.next:
                slow = slow.next
                fast = fast.next.next
            return slow.data
    else :
        return 



def takeInput():
    inputList = [int(u) for u in input().split()]
    head = None 
    tail = None 
    for curr in inputList:
        if curr == -1 :
            break
        else :
            newNode = Node(curr)
            if head is None:
                head = newNode
                tail = newNode
            else :
                tail.next = newNode
                tail = newNode
    return head


def printLL(head):
    while head :
        print(head.data,end = ' ')
        head = head.next 
    print()

head = takeInput()
printLL(head)
value = midValue(head)
print(value)
# Out:
# 1 2 3 4
# 2

# %%
class Node :
    def __init__(self,data):
        self.data = data 
        self.next = None 

def midValue(head):
    slow = head 
    fast = head 
    while fast. next and fast.next.next :
        slow = slow.next 
        fast = fast.next.next  
    return slow.data 




def takeInput():
    inputList = [int(u) for u in input().split()]
    head = None 
    tail = None 
    for curr in inputList:
        if curr == -1 :
            break
        else :
            newNode = Node(curr)
            if head is None:
                head = newNode
                tail = newNode
            else :
                tail.next = newNode
                tail = newNode
    return head


def printLL(head):
    while head :
        print(head.data,end = ' ')
        head = head.next 
    print()

head = takeInput()
printLL(head)
value = midValue(head)
print(value)
# Out:
# 1 2 3 4 5 6 7
# 4

# %% [markdown]
# ### merging two sorted linked list

# %%
class Node :
    def __init__(self,data):
        self.data = data 
        self.next = None 


def merging(head1,head2):
    fH = None 
    fT = None 
    h1 = head1
    h2 = head2   
    if h1 is None :
        return h2
    elif h2 is None :               
        return h1 
    while h1 and h2  :
        if h1.data < h2.data :
            if fH is None :
                fH = h1
                fT = h1
                h1 = h1.next 
            else :
                fT.next = h1
                fT = fT.next 
                h1 = h1.next 
        else :
            if fH is None :
                fH = h2 
                fT = h2 
                h2 = h2.next
            else :
                fT.next = h2
                fT = h2 
                h2 = h2.next
    if h1 is not None :
        fT.next = h1
    else :
        fT.next = h2
    return fH


def printLL(head):
    while head :
        print(head.data,end = ' ')
        head = head.next 
    print()
            

def takeInput():
    inputList = [int(u) for u in input().split()]
    head = None 
    tail = None 
    for curr in inputList:
        if curr == -1 :
            break
        else :
            newNode = Node(curr)
            if head is None:
                head = newNode
                tail = newNode
            else :
                tail.next = newNode
                tail = newNode
    return head

head1 = takeInput()
head2 = takeInput()
value = merging(head1, head2)
printLL(value)
# Out:
# 1 3 4 4 5 6 6 8

# %% [markdown]
# ### merge sort on linked list
# we need to create the new hade value because linked list are note mutable we have to change the refference of the head

# %%
class Node :
    def __init__(self,data):
        self.data = data 
        self.next = None 
        
def midValue(head):
    slow = head 
    fast = head 
    while fast. next and fast.next.next :
        slow = slow.next 
        fast = fast.next.next  
    return slow



def merge(head):
    if head is None or head.next is None :
        return head 
    mid = midValue(head)
    m = mid.next 
    mid.next = None 
    l = head 
    newHead1 = merge(l)
    newHead2 = merge (m)      
    value = merging(newHead1,newHead2)
    return value


def merging (M,L):
    h1 = M 
    h2 = L 
    fH = None 
    fT = None 
    if h1 is None :
        return h2 
    elif h2 is None :
        return h1 
    while h1 and h2 :

        if h1.data < h2.data :
            if fH is None :
                fH = h1 
                fT = h1 
                h1 = h1.next 
            else :
                fT.next = h1 
                fT = fT.next 
                h1 = h1.next
        else :
            if fH is None :
                fH = h2 
                fT = h2 
                h2 = h2.next 
            else :
                fT.next = h2 
                fT = fT.next 
                h2 = h2.next 
    if h1 is not None :
        fT.next = h1 
    else :
        fT.next = h2
    return fH

    





def takeInput():
    inputList = [int(u) for u in input().split()]
    head = None 
    tail = None 
    for curr in inputList:
        if curr == -1 :
            break
        else :
            newNode = Node(curr)
            if head is None:
                head = newNode
                tail = newNode
            else :
                tail.next = newNode
                tail = newNode
    return head 

def printLL(head):
    while head :
        print(head.data,end = ' ')
        head = head.next 
    print()


t = int(input())
while t > 0 :
    head = takeInput()
    value = merge(head)
    printLL(value)
    t-=1
# Out:
# 1 2 3

# %%
class Student :
    name = 'aman'
    def __str__(self) :
        return self.name
# Out:
# khalid
# 'aman'
