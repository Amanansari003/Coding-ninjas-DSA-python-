# %% [markdown]
# ### bsf

# %%
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for j in range(self.nVertices)] for i in range(self.nVertices)]

    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1 
    
    def bsfHelper(self,sv,visited):
        q = queue.Queue()
        q.put(sv)
        visited[sv] = True
        while q.empty() is False :
            front = q.get()
            print(front,end = " ")
            for i in range(self.nVertices):
                if self.adjMatrix[front][i] > 0 and visited[i] is False :
                        q.put(i)
                        visited[i] = True 

    def bsf(self):
            visited = [False for i in range(self.nVertices)]
            for i in range(self.nVertices):
                if visited[i] is False :
                    self.bsfHelper(i,visited) 
            


li = [int(i) for i in input().split()]
nVertices = li[0] 
edgesPair = li[1]
g = Graph(nVertices)
if edgesPair != 0 :
    for i in range(edgesPair):
        v1, v2 = input().split()
        g.addEdge(int(v1),int(v2))
else :
    for i in range(nVertices):
        g.addEdge(i,i)

if nVertices != 0 :     
    g.bsf()

# %% [markdown]
# ### has path

# %%
from sys import setrecursionlimit 
setrecursionlimit(10**6)
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for j in range(self.nVertices)] for i in range(self.nVertices)]

    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1 
    
    def hasPathHelper(self,sv,ev,visited):
        if sv == ev :
            return True
        visited[sv] = True 

        for i in range(self.nVertices):
            if self.adjMatrix[sv][i] == 1 and visited[i] is False :
                val = self.hasPathHelper(i,ev,visited)
                if val :
                    return True 
        return False 

    def hasPath(self,starting_vertives,ending_vertices):
            visited = [False for i in range(self.nVertices)]
            return self.hasPathHelper(starting_vertives,ending_vertices,visited)
    
            


li = [int(i) for i in input().split()]
nVertices = li[0] 
edgesPair = li[1]
g = Graph(nVertices)
if edgesPair != 0 :
    for i in range(edgesPair):
        v1, v2 = input().split()
        g.addEdge(int(v1),int(v2))
li = [int(i) for i in input().split()]
sv = li[0]
ev = li[1]
val = g.hasPath(sv,ev)
if val :
    print("true")
else :
    print("false")

# %% [markdown]
# ### get path dsf

# %%
from sys import setrecursionlimit 
setrecursionlimit(10**6)    

class Graph:
    def __init__(self,nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for j in range(self.nVertices)] for i in range(self.nVertices)]

    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1 
    
    def hasPathDsfHelper(self,sv,ev,visited):

        if sv == ev :
            return  [sv]
        visited[sv] = True 
        for i in range(self.nVertices):
            if self.adjMatrix[sv][i] == 1 and visited[i] is False :
                val = self.hasPathDsfHelper(i,ev,visited)
                if val != None :
                    val.append(sv)
                    return val
        return None 
                
    def hasPathDsf(self,starting_vertives,ending_vertices):
            visited = [False for i in range(self.nVertices)]
            return self.hasPathDsfHelper(starting_vertives,ending_vertices,visited)


li = [int(i) for i in input().split()]
nVertices = li[0] 
edgesPair = li[1]
g = Graph(nVertices)
if edgesPair != 0 :
    for i in range(edgesPair):
        v1, v2 = input().split()
        g.addEdge(int(v1),int(v2))
li = [int(i) for i in input().split()]
sv = li[0]
ev = li[1]
li = g.hasPathDsf(sv,ev)
if li != None :
    for i in li :
        print(i,end = " ")

# %% [markdown]
# ### get path bsf

# %%
from sys import setrecursionlimit 
setrecursionlimit(10**6)    
import queue
class Graph:
    def __init__(self,nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [[0 for j in range(self.nVertices)] for i in range(self.nVertices)]

    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2] = 1
        self.adjMatrix[v2][v1] = 1 
    
    def hasPathBsfHelper(self,sv,ev,visited):
        q = queue.Queue()
        q.put(sv)
        map = { }
        visited[sv] = True
        while q.empty() is False:
            front = q.get()
            for i in range(self.nVertices):
                if self.adjMatrix[front][i] == 1 and not visited[i] :
                    q.put(i)
                    map[i] = front  
                    visited[i] = True 

                    if i == ev :
                        ans = [ ]
                        ans.append(ev)
                        value = map[i]

                        while value!=sv :
                            ans.append(value)
                            value = map[value]
                        ans.append(value)
                        return ans 
        return [ ]


    def hasPathBsf(self,starting_vertives,ending_vertices):
            visited = [False for i in range(self.nVertices)]
            return self.hasPathBsfHelper(starting_vertives,ending_vertices,visited)
    
            


li = [int(i) for i in input().split()]
nVertices = li[0] 
edgesPair = li[1]
g = Graph(nVertices)
for i in range(edgesPair):
    v1, v2 = input().split()
    g.addEdge(int(v1),int(v2))
li = [int(i) for i in input().split()]
sv = li[0]
ev = li[1]
li = g.hasPathBsf(sv,ev)
for i in li :
    print(i,end = " ")

# %% [markdown]
# ### is connected

# %%
from sys import stdin, setrecursionlimit
setrecursionlimit(10**6)

class Graph :
    def __init__(self,nvertices):
        self.nVertices = nvertices
        self.adjMatrix = [[0 for j in range(nvertices)] for i in range(nvertices)]

    def addEdge(self,v1,v2):
        self.adjMatrix[v1][v2] = 1 
        self.adjMatrix[v2][v1] = 1
    
    def __dfsHelper(self,sv,visited):
        visited[sv] = True 
        for i in range(self.nVertices):
            if (self.adjMatrix[sv][i] > 0 and visited[i] is False):
                self.__dfsHelper(i,visited)

    def connected(self) :
        visited = [ False for i in range(self.nVertices)]
        self.__dfsHelper(0,visited)
        for val in visited:
            if not val :
                return False 
        return True

li = stdin.readline().strip().split()
nVertices = int(li[0])
edgesPair = int(li[1])

if nVertices == 0 :
    print("true")
else :
    g = Graph(nVertices)
    for i in range(edgesPair):
        li = stdin.readline().strip().split()
        v1 = li[0]
        v2 = li[1]
        g.addEdge(int(v1),int(v2)) 
    val = g.connected( )
    if val :
        print("true")
    else :
        print("false")

# %% [markdown]
# ### all connected component

# %%
from sys import setrecursionlimit
setrecursionlimit(10**6)
class Graph :

    def __init__(self,nVertices) :
        self.nVertices = nVertices
        self.adjMatrix = [[0 for i in range(nVertices)] for j in range(nVertices)]

    def addEdges(self,v1,v2):
        self.adjMatrix[v1][v2] = 1 
        self.adjMatrix[v2][v1] = 1 

    def dsfhelper(self, sv,visited,arr):
        arr.append(sv)
        visited[sv] = True 
        for i in range(self.nVertices):
            if self.adjMatrix[sv][i] == 1 and visited[i] is False :
                self.dsfhelper(i,visited,arr)
        return arr 
    def dsf(self):
        visited = [False for i in range(self.nVertices)]
        li = [ ]
        for i in range(self.nVertices) :
            if visited[i] is False :
               val = self.dsfhelper(i,visited,[])
               li.append(val)
        return li 

li = [int(i) for i in input().split()]
V = li[0]
E = li[1]
if V!= 0 :
    g = Graph(V)
    for i in range(E):
        li = [int(i) for i in input().split()]
        v1 = li[0]
        v2 = li[1]
        g.addEdges(v1,v2)
    val = g.dsf()
    for i in val:
        i.sort()
        for j in i :
            print(j,end = ' ')
        print()

# %% [markdown]
# #### krushkals algorithum

# %%
### inputs class
class Edge :
	def __init__(self,src,dest,wt):
		self.src = src 
		self.dest = dest 
		self.wt  = wt 

# checking for the parent 

def getParent(v, parent):
	if v == parent[v]:
		return v 
	return getParent(parent[v],parent)

### krushkal algorithum 
def krushkalsAlgo(edges,nVertices):
	parent = [i for i in range(nVertices)]
	edges = sorted(edges,key = lambda edge : edge.wt)
	count = 0 
	output =  []
	i = 0 
	while count < (nVertices-1) :
		current_edge = edges[i]
		srcParent = getParent(current_edge.src,parent)
		destParent = getParent(current_edge.dest,parent)

		if srcParent != destParent :
			output.append(current_edge)
			count+=1
			parent[srcParent] = destParent
		i+=1
	return output  


## input format 
li = [int(i) for i in input().split()]
nVertices = li[0]
nEdges = li[1]
edges = []
for i in range(nEdges):
	currrent_edges = [int(entry) for entry in input().split()]
	src = currrent_edges[0]
	dest = currrent_edges[1]
	wt = currrent_edges[2]
	edge = Edge(src,dest,wt)
	edges.append(edge)

output = krushkalsAlgo(edges,nVertices)
print( )
for edge in output :
	if edge.src <= edge.dest :  
		print(str(edge.src)+" "+str(edge.dest)+" "+str(edge.wt))
	else :
		print(str(edge.dest)+" "+str(edge.src)+" "+str(edge.wt))

# %% [markdown]
# ### prims algo

# %%
## Read input as specified in the question.
## Print output as specified in the question.
from sys import maxsize

class Graph :

    def __init__(self,nVertices) :
        self.nVertices = nVertices
        self.adjMatrix = [[0 for i in range(nVertices)] for j in range(nVertices)]

    def addEdges(self,v1,v2,wt):
        self.adjMatrix[v1][v2] = wt 
        self.adjMatrix[v2][v1] = wt
    
    def __getminiVertices(self,visited,weight):
        min_vertex = -1 

        for i in range(self.nVertices):
            if visited[i] is False and (min_vertex == -1 or weight[min_vertex] > weight[i]):
                min_vertex = i 
        return min_vertex

    def prims(self):
        visited = [False for i in range(self.nVertices)]
        parent = [-1 for i in range(self.nVertices)]
        weight = [maxsize for i in range (self.nVertices)]
        weight[0] = 0 

        for i in range(self.nVertices-1):
            min_vertice = self.__getminiVertices(visited,weight)
            visited[min_vertice] = True

            ### explore all neighbour of mini vertices which is not visited 
            #and update the weight corresponding to them  

            for j in range(self.nVertices):
                if self.adjMatrix[min_vertice][j] > 0 and visited[j] is False :
                    if weight[j] > self.adjMatrix[min_vertice][j] :
                        weight[j] = self.adjMatrix[min_vertice][j]
                        parent[j] = min_vertice

        for i in range(1,self.nVertices) :
            if i < parent[i] :
                print(str(i),str(parent[i]), str(weight[i]))
            else :
                print(str(parent[i]),str(i),str(weight[i]))

                    
## input for the prime algo 
li = [int(i) for i in input().split()]
nVertices = li[0]
E = li[1]
g = Graph(nVertices)
for i in range(E):
    currrent_input = [int(i) for i in input().split()]
    g.addEdges(currrent_input[0],currrent_input[1],currrent_input[2])

g.prims()

# %% [markdown]
# ### Dijkstra's Algorithm

# %%
from sys import maxsize

class Graph :
    def __init__(self,nVerrtices):
        self.nVertices = nVerrtices
        self.adjmatrix = [[0 for i in range(self.nVertices)] for j in range(self.nVertices)]

    def addEdges(self,v1,v2,wt):
        self.adjmatrix[v1][v2] = wt
        self.adjmatrix[v2][v1] = wt 

    def __getMinVertex(self,visited,distance):
        minVertex = -1 

        for i in range(self.nVertices):
            if visited[i] is False and (minVertex == -1 or distance[minVertex] > distance[i]):
                minVertex = i 
        return minVertex

    def dijkastraAlgo(self):
        visited = [False for i in range(self.nVertices)]
        distance = [maxsize for i in range(self.nVertices)]
        distance[0] = 0 
    
        for i in range(self.nVertices-1):
            miniWeightVertex = self.__getMinVertex(visited,distance)
            visited[miniWeightVertex] = True 

            for j in range(self.nVertices):
                if self.adjmatrix[miniWeightVertex][j]>0 and visited[j] is False :
                    if distance[j] > distance[miniWeightVertex]+self.adjmatrix[miniWeightVertex][j] :
                        distance[j] = distance[miniWeightVertex]+self.adjmatrix[miniWeightVertex][j] 
        
        for i in range(len(distance)):
            print(i,distance[i])



li = [int(i) for i in input().split()]
nVertices = li[0]
nEdges = li[1]
g = Graph(nVertices)
for i in range(nEdges):
    l = [int(i) for i in input().split()]
    g.addEdges(l[0],l[1],l[2])

g.dijkastraAlgo( )
# Out:
# 0 0
# 1 3
# 2 4
# 3 5

# %%
import sys
class Graph:
    
    def __init__(self,nVertices):
        self.nVertices = nVertices
        self.adjMatrix = [ [ 0 for i in range(nVertices)] for j in range(nVertices)]
        
    def addEdge(self,v1,v2,wt):

        self.adjMatrix[v1][v2] = wt
        self.adjMatrix[v2][v1] = wt

    def __getMinVertexD(self,visited,weight):
        minVertex = -1
        for i in range(self.nVertices):
            if(visited[i] is False and (minVertex == -1 or (weight[minVertex] > weight[i]))):
                minVertex = i
        return minVertex
    
    def djikstra(self):
        
        visited = [False for i in range(self.nVertices)]
        dist = [sys.maxsize for i in range(self.nVertices)]
        dist[0] = 0
        for i in range(self.nVertices - 1):
            minVertex = self.__getMinVertexD(visited,dist)
            visited[minVertex] = True
            
            for j in range(self.nVertices):
                if (self.adjMatrix[minVertex][j] > 0 and visited[j] is False):
                    if(dist[j] > dist[minVertex] + self.adjMatrix[minVertex][j]):
                        dist[j] = dist[minVertex] + self.adjMatrix[minVertex][j]
                        
        for i in range(self.nVertices):
            print(str(i) + " " + str(dist[i]))
            
li = [int(ele) for ele in input().split()]
n = li[0]
E = li[1]
g = Graph(n)
for i in range(E):
    curr_edge = [int(ele) for ele in input().split()]
    g.addEdge(curr_edge[0],curr_edge[1],curr_edge[2])

g.djikstra()

# %%
def encryption(arr):
    if len(arr) == 2 :
        return str(arr[0])+str(arr[1])

    output = []
    for i in range(len(arr)-1):
        num = (arr[i]+arr[i+1])%10
        output.append(num)
    
    return encryption(output)




n = int(input())
l = [int(i) for i in input().split()]
if n == 2 :
    print(str(l[0]%10)+str(l[1]%10))
elif n >2 :
    val = encryption(l)
    print(val)

# %%
def encryption(arr):
    output = [ ]
    if len(arr) <=1 :
        return(str(arr[0]))
    
    while len(arr)!= 2 :
        for num in range(len(arr)-1):
            val = arr[num]+arr[num+1]
            if val > 9 :
                val = val%10
            output.append(val)
        
        arr = output
        output = []
    return str(arr[0])+str(arr[1])


n = int(input())
l = [int(i) for i in input().split()]
val = encryption(l)
print(val)
# if n == 2 :
#     print(str(l[0]%10)+str(l[1]%10))
# elif n >2 :
#     val = encryption(l)
#     print(val)
# Out:
# 82
